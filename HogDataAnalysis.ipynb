# %% [markdown]
# # Hog data analysis 2024

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./archive.csv")

# %%
df.head()
# Out:
#    Year Punxsutawney Phil  February Average Temperature  \
# 0  1886         No Record                           NaN
# 1  1887       Full Shadow                           NaN
# 2  1888       Full Shadow                           NaN
# 3  1889         No Record                           NaN
# 4  1890         No Shadow                           NaN
#
#    February Average Temperature (Northeast)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    February Average Temperature (Midwest)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    February Average Temperature (Pennsylvania)  March Average Temperature  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 10 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Year                                         132 non-null    object
#  1   Punxsutawney Phil                            131 non-null    object
#  2   February Average Temperature                 123 non-null    float64
#  3   February Average Temperature (Northeast)     123 non-null    float64
#  4   February Average Temperature (Midwest)       123 non-null    float64
#  5   February Average Temperature (Pennsylvania)  123 non-null    float64
#  6   March Average Temperature                    123 non-null    float64
#  7   March Average Temperature (Northeast)        123 non-null    float64
#  8   March Average Temperature (Midwest)          123 non-null    float64
# ...

# %%
df.shape
# Out:
# (132, 10)

# %%
df.tail()
# Out:
#           Year Punxsutawney Phil  February Average Temperature  \
# 127       2013         No Shadow                         34.77
# 128       2014       Full Shadow                         32.13
# 129       2015       Full Shadow                         32.99
# 130       2016         No Shadow                         39.47
# 131  1901-2000               NaN                         33.82
#
#      February Average Temperature (Northeast)  \
# 127                                      25.3
# 128                                      21.0
# 129                                      12.1
# 130                                      28.1
# 131                                      22.5
#
#      February Average Temperature (Midwest)  \
# 127                                    33.4
# 128                                    27.1
# 129                                    23.4
# 130                                    36.9
# 131                                    32.9
#
# ...

# %%
# Setting Year as the index
df.set_index('Year')
# Out:
#           Punxsutawney Phil  February Average Temperature  \
# Year
# 1886              No Record                           NaN
# 1887            Full Shadow                           NaN
# 1888            Full Shadow                           NaN
# 1889              No Record                           NaN
# 1890              No Shadow                           NaN
# ...                     ...                           ...
# 2013              No Shadow                         34.77
# 2014            Full Shadow                         32.13
# 2015            Full Shadow                         32.99
# 2016              No Shadow                         39.47
# 1901-2000               NaN                         33.82
#
#            February Average Temperature (Northeast)  \
# Year
# 1886                                            NaN
# 1887                                            NaN
# 1888                                            NaN
# ...

# %%
df["Punxsutawney Phil"].value_counts()
# Out:
# Punxsutawney Phil
# Full Shadow       102
# No Shadow          16
# No Record          12
# Partial Shadow      1
# Name: count, dtype: int64

# %%
# To find the row when Punxsutawney Phil is equal to Partial Shadow

df.loc[df["Punxsutawney Phil"] == "Partial Shadow"]
# Out:
#     Year Punxsutawney Phil  February Average Temperature  \
# 56  1942    Partial Shadow                         30.74
#
#     February Average Temperature (Northeast)  \
# 56                                      20.1
#
#     February Average Temperature (Midwest)  \
# 56                                    29.7
#
#     February Average Temperature (Pennsylvania)  March Average Temperature  \
# 56                                         23.2                      41.31
#
#     March Average Temperature (Northeast)  \
# 56                                   35.7
#
#     March Average Temperature (Midwest)  \
# 56                                 44.1
#
#     March Average Temperature (Pennsylvania)
# 56                                      37.8

# %% [markdown]
# # Getting more data from the groundhog-day API
#
# ## https://groundhog-day.com/api

# %%
import requests

# %%
res = requests.get("https://groundhog-day.com/api/v1/groundhogs")

# %%
# What we have sent
res.headers
# Out:
# {'cross-origin-opener-policy': 'same-origin', 'cross-origin-resource-policy': 'cross-origin', 'origin-agent-cluster': '?1', 'referrer-policy': 'no-referrer', 'strict-transport-security': 'max-age=15552000; includeSubDomains', 'x-content-type-options': 'nosniff', 'x-dns-prefetch-control': 'off', 'x-download-options': 'noopen', 'x-frame-options': 'SAMEORIGIN', 'x-permitted-cross-domain-policies': 'none', 'x-xss-protection': '0', 'access-control-allow-origin': '*', 'content-type': 'application/json; charset=utf-8', 'etag': 'W/"22f72-QKdrSZWIJuNruc3YNLh/zTY/yIo"', 'vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Date': 'Sat, 03 Feb 2024 19:59:14 GMT', 'Server': 'Google Frontend', 'Cache-Control': 'private', 'Transfer-Encoding': 'chunked'}

# %%
res.json()
# Out:
# {'groundhogs': [{'id': 1,
#    'slug': 'punxsutawney-phil',
#    'shortname': 'Phil',
#    'name': 'Punxsutawney Phil',
#    'city': 'Punxsutawney',
#    'region': 'Pennsylvania',
#    'country': 'USA',
#    'coordinates': '40.9311988,-78.9622483',
#    'source': 'https://www.groundhog.org/history-past-predictions',
#    'contact': '',
#    'currentPrediction': 'https://www.npr.org/2024/02/02/1228547493/groundhog-day-punxsutawney-phil-spring',
#    'isGroundhog': 1,
#    'type': 'Groundhog',
#    'active': 1,
#    'successor': '',
#    'description': 'Punxsutawney Phil is a superstar prognosticating groundhog from Punxsutawney, Pennsylvania. He makes his predictions from his burrow on Gobler’s Knob. According to legend, Phil has made weather prognostications since 1886, owing his improbably long life to the miraculous “groundhog nog” administered at the annual Groundhog Picnic.',
#    'image': 'https://groundhog-day.com/images/ghogs/punxsutawney-phil.jpeg',
# ...
